# %% [markdown]
# # Importar librerias y data

# %%
import pandas as pd

# %%
# de aqui se toma la data de usuarios y reviews
tx_df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/data-nueva/Houston-TX.xlsx", parse_dates=["review_datetime_utc"])
ca_df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/data-nueva/Los Angeles - CA.xlsx", parse_dates=["review_datetime_utc"])
ny_df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/data-nueva/New York - NY.xlsx", parse_dates=["review_datetime_utc"])
fl_df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/data-nueva/Orlando - FL.xlsx", parse_dates=["review_datetime_utc"])
nv_df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/data-nueva/Reno - NV.xlsx", parse_dates=["review_datetime_utc"])

# %%
# de aqui se toma la data de hoteles
business_tx_df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/data-nueva/business-houston.xlsx")
business_ca_df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/data-nueva/business-los-angeles.xlsx")
business_ny_df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/data-nueva/business-new-york.xlsx")
business_fl_df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/data-nueva/business-orlando.xlsx")
business_nv_df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/data-nueva/business-reno.xlsx")

# %% [markdown]
# # Hoteles

# %% [markdown]
# ## Texas

# %%
business_tx_df.head(2)
# Out:
#                            query  \
# 0  hotel, 77040, Houston, TX, US
# 1  hotel, 77040, Houston, TX, US
#
#                                             name  \
# 0     Hilton Garden Inn Houston NW America Plaza
# 1  Courtyard by Marriott Houston NW/290 Corridor
#
#                                                 site   type  \
# 0  https://www.hilton.com/en/hotels/houamgi-hilto...  Hotel
# 1  https://www.marriott.com/en-us/hotels/houcn-co...  Hotel
#
#                           subtypes category            phone  \
# 0                            Hotel   hotels  +1 713-896-6700
# 1  Hotel, Meeting planning service   hotels  +1 832-786-6400
#
#                              full_address                         borough  \
# 0  14919 Northwest Fwy, Houston, TX 77040                            None
# 1      6708 Gessner Rd, Houston, TX 77040  Fairbanks / Northwest Crossing
#
#                 street  ... reservation_links  booking_appointment_link  \
# ...

# %%
business_tx_df.shape
# Out:
# (200, 59)

# %%
business_tx_df.isna().mean()
# Out:
# query                       0.000
# name                        0.000
# site                        0.180
# type                        0.000
# subtypes                    0.000
# category                    0.000
# phone                       0.045
# full_address                0.000
# borough                     0.000
# street                      0.000
# city                        0.000
# postal_code                 0.000
# state                       0.000
# us_state                    0.000
# country                     0.000
# country_code                0.000
# latitude                    0.000
# longitude                   0.000
# time_zone                   0.000
# plus_code                   1.000
# area_service                0.000
# rating                      0.035
# reviews                     0.035
# reviews_link                0.300
# reviews_tags                1.000
# reviews_per_score           0.035
# reviews_per_score_1         0.035
# ...

# %%
chosen_columns = ["name", "subtypes", "full_address", "state", "latitude", "longitude", "rating", "reviews", "place_id", "google_id"]
business_tx_df = business_tx_df[chosen_columns]
business_tx_df.head(2)
# Out:
#                                             name  \
# 0     Hilton Garden Inn Houston NW America Plaza
# 1  Courtyard by Marriott Houston NW/290 Corridor
#
#                           subtypes                            full_address  \
# 0                            Hotel  14919 Northwest Fwy, Houston, TX 77040
# 1  Hotel, Meeting planning service      6708 Gessner Rd, Houston, TX 77040
#
#    state   latitude  longitude  rating  reviews                     place_id  \
# 0  Texas  29.868159 -95.546791     4.2    985.0  ChIJ-Yu5I-7PQIYRuY2a8Z0NbLQ
# 1  Texas  29.865333 -95.540781     4.3    584.0  ChIJ_1vcRPPPQIYRrabqIHGt8vc
#
#                                google_id
# 0  0x8640cfee23b98bf9:0xb46c0d9df19a8db9
# 1  0x8640cff344dc5bff:0xf7f2ad7120eaa6ad

# %%
business_tx_df.rename(columns={"name":"business_name", "subtypes": "category", "full_address":"address",
                               "rating": "avg_rating", "reviews": "num_of_reviews"}, inplace=True)

# %%
business_tx_df["state"].unique()
# Out:
# array(['Texas', 'TX'], dtype=object)

# %%
business_tx_df["state"] = "TX"

# %%
business_tx_df.head(2)
# Out:
#                                    business_name  \
# 0     Hilton Garden Inn Houston NW America Plaza
# 1  Courtyard by Marriott Houston NW/290 Corridor
#
#                           category                                 address  \
# 0                            Hotel  14919 Northwest Fwy, Houston, TX 77040
# 1  Hotel, Meeting planning service      6708 Gessner Rd, Houston, TX 77040
#
#   state   latitude  longitude  avg_rating  num_of_reviews  \
# 0    TX  29.868159 -95.546791         4.2           985.0
# 1    TX  29.865333 -95.540781         4.3           584.0
#
#                       place_id                              google_id
# 0  ChIJ-Yu5I-7PQIYRuY2a8Z0NbLQ  0x8640cfee23b98bf9:0xb46c0d9df19a8db9
# 1  ChIJ_1vcRPPPQIYRrabqIHGt8vc  0x8640cff344dc5bff:0xf7f2ad7120eaa6ad

# %%
business_tx_df.shape
# Out:
# (200, 10)

# %% [markdown]
# ## Resto de estados

# %%
def etl_hoteles(df):
  chosen_columns = ["name", "subtypes", "full_address", "state", "latitude", "longitude", "rating", "reviews", "place_id", "google_id"]
  df = df[chosen_columns]
  df.rename(columns={"name":"business_name", "subtypes": "category", "full_address": "address",
                    "rating": "avg_rating", "reviews": "num_of_reviews"}, inplace=True)
  return df

# %%
ca_business = etl_hoteles(business_ca_df)
# Out:
# <ipython-input-10-99774e761093>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"name":"business_name", "subtypes": "category", "full_address": "address",

# %%
ca_business["state"].unique()
# Out:
# array(['California', 'CA'], dtype=object)

# %%
ca_business["state"] = "CA"
# Out:
# <ipython-input-13-b4ef96e650b3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ca_business["state"] = "CA"

# %%
ca_business.head(2)
# Out:
#                                        business_name           category  \
# 0  Ramada Plaza by Wyndham West Hollywood Hotel &...  Hotel, Inn, Motel
# 1                               Mondrian Los Angeles              Hotel
#
#                                             address state   latitude  \
# 0  8585 Santa Monica Blvd, West Hollywood, CA 90069    CA  34.088697
# 1        8440 Sunset Blvd, West Hollywood, CA 90069    CA  34.094554
#
#     longitude  avg_rating  num_of_reviews                     place_id  \
# 0 -118.378805         3.6          1134.0  ChIJV_pvpbu-woARQ85y4CokD4s
# 1 -118.374196         4.1          1627.0  ChIJNVvaZb6-woAR6cPPdx0dR5A
#
#                                google_id
# 0  0x80c2bebba56ffa57:0x8b0f242ae072ce43
# 1  0x80c2bebe65da5b35:0x90471d1d77cfc3e9

# %%
ca_business.shape
# Out:
# (150, 10)

# %%
ny_business = etl_hoteles(business_ny_df)
# Out:
# <ipython-input-10-99774e761093>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"name":"business_name", "subtypes": "category", "full_address": "address",

# %%
ny_business["state"].unique()
# Out:
# array(['New York', 'NY', 'New Jersey'], dtype=object)

# %%
ny_business["state"] = ny_business["state"].str.replace("New York", "NY")
# Out:
# <ipython-input-18-fb264333b2ef>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ny_business["state"] = ny_business["state"].str.replace("New York", "NY")

# %%
ny_business.head(2)
# Out:
#                                business_name category  \
# 0               Hyatt Grand Central New York    Hotel
# 1  Library Hotel by Library Hotel Collection    Hotel
#
#                                              address state   latitude  \
# 0  At Grand Central Terminal, 109 E 42nd St, New ...    NY  40.752062
# 1  299 Madison Aveneue, E 41st St, New York, NY 1...    NY  40.752170
#
#    longitude  avg_rating  num_of_reviews                     place_id  \
# 0 -73.976299         4.1          6617.0  ChIJsS1xLQJZwokRGfXJPMwXA1A
# 1 -73.979532         4.6           633.0  ChIJebujAAFZwokRKeKF6sJ0lNQ
#
#                                google_id
# 0  0x89c259022d712db1:0x500317cc3cc9f519
# 1  0x89c2590100a3bb79:0xd49474c2ea85e229

# %%
ny_business.shape
# Out:
# (200, 10)

# %%
fl_business = etl_hoteles(business_fl_df)
# Out:
# <ipython-input-10-99774e761093>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"name":"business_name", "subtypes": "category", "full_address": "address",

# %%
fl_business["state"].unique()
# Out:
# array(['Florida', 'FL'], dtype=object)

# %%
fl_business["state"] = "FL"
# Out:
# <ipython-input-23-8f1857f529b1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fl_business["state"] = "FL"

# %%
fl_business.head(2)
# Out:
#                                        business_name           category  \
# 0      La Quinta Inn by Wyndham Orlando Airport West  Hotel, Inn, Motel
# 1  Country Inn & Suites by Radisson, Orlando Airp...         Hotel, Bar
#
#                                 address state   latitude  longitude  \
# 0  7931 Daetwyler Dr, Orlando, FL 32812    FL  28.452035 -81.337750
# 1     5440 Forbes Pl, Orlando, FL 32812    FL  28.459817 -81.313818
#
#    avg_rating  num_of_reviews                     place_id  \
# 0         3.3          2214.0  ChIJjcLN4ixj54gRnuP_LmRNbp4
# 1         3.7          1752.0  ChIJI0kTPhRj54gRpEXr90AE7_c
#
#                                google_id
# 0  0x88e7632ce2cdc28d:0x9e6e4d642effe39e
# 1  0x88e763143e134923:0xf7ef0440f7eb45a4

# %%
fl_business.shape
# Out:
# (200, 10)

# %%
nv_business = etl_hoteles(business_nv_df)
# Out:
# <ipython-input-10-99774e761093>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"name":"business_name", "subtypes": "category", "full_address": "address",

# %%
nv_business["state"].unique()
# Out:
# array(['Nevada', 'California'], dtype=object)

# %%
nv_business["state"] = nv_business["state"].str.replace("Nevada", "NV")
nv_business["state"] = nv_business["state"].str.replace("California", "CA")
# Out:
# <ipython-input-28-2fd3b7b7f565>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nv_business["state"] = nv_business["state"].str.replace("Nevada", "NV")
# <ipython-input-28-2fd3b7b7f565>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nv_business["state"] = nv_business["state"].str.replace("California", "CA")

# %%
nv_business.head(2)
# Out:
#                    business_name           category  \
# 0             Circus Circus Reno              Hotel
# 1  La Quinta Inn by Wyndham Reno  Hotel, Inn, Motel
#
#                            address state   latitude   longitude  avg_rating  \
# 0  500 N Sierra St, Reno, NV 89503    NV  39.531446 -119.815709         4.0
# 1   4001 Market St, Reno, NV 89502    NV  39.510086 -119.781952         2.8
#
#    num_of_reviews                     place_id  \
# 0         15912.0  ChIJ8ZZtmjZHmYARPmy0CY53NYo
# 1          1708.0  ChIJs41faGQ_mYAR83uilE_On10
#
#                                google_id
# 0  0x809947369a6d96f1:0x8a35778e09b46c3e
# 1  0x80993f64685f8db3:0x5d9fce4f94a27bf3

# %%
nv_business.shape
# Out:
# (150, 10)

# %% [markdown]
# Ahore se unen las tablas

# %%
hotels_list = [business_tx_df, nv_business, fl_business, ca_business, ny_business]
business_nueva_data = pd.concat(hotels_list, ignore_index=True)

# %%
business_nueva_data.shape
# Out:
# (900, 10)

# %%
states_list = ["CA", "TX", "FL", "NY", "NV"]
business_nueva_data = business_nueva_data[business_nueva_data["state"].isin(states_list)]

# %%
business_nueva_data.isna().mean()
# Out:
# business_name     0.000000
# category          0.001115
# address           0.000000
# state             0.000000
# latitude          0.000000
# longitude         0.000000
# avg_rating        0.033445
# num_of_reviews    0.033445
# place_id          0.000000
# google_id         0.000000
# dtype: float64

# %%
business_nueva_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Reviews y usuarios

# %% [markdown]
# ## Texas

# %%
tx_df.shape
# Out:
# (2235, 26)

# %%
tx_df.isna().mean()
# Out:
# query                                  0.000000
# name                                   0.000000
# google_id                              0.000000
# place_id                               0.000000
# location_link                          0.000000
# reviews_link                           0.000000
# reviews_per_score                      0.000000
# reviews                                0.000000
# rating                                 0.000000
# review_id                              0.000000
# author_link                            0.000000
# author_title                           0.000000
# author_id                              0.217450
# author_image                           0.000000
# review_text                            0.000000
# review_img_url                         0.914541
# review_img_urls                        0.914541
# owner_answer                           0.560179
# owner_answer_timestamp                 0.560179
# owner_answer_timestamp_datetime_utc    0.560179
# ...

# %%
tx_df.dtypes
# Out:
# query                                          object
# name                                           object
# google_id                                      object
# place_id                                       object
# location_link                                  object
# reviews_link                                   object
# reviews_per_score                              object
# reviews                                         int64
# rating                                        float64
# review_id                                      object
# author_link                                    object
# author_title                                   object
# author_id                                      object
# author_image                                   object
# review_text                                    object
# review_img_url                                 object
# review_img_urls                                object
# ...

# %%
tx_df.head(2)
# Out:
#                      query                                       name  \
# 0  hotel, Houston, TX, USA  Comfort Inn & Suites SW Houston Sugarland
# 1  hotel, Houston, TX, USA  Comfort Inn & Suites SW Houston Sugarland
#
#                                google_id                     place_id  \
# 0  0x8640e8086ca548b1:0x477dd129975bfff8  ChIJsUilbAjoQIYR-P9blynRfUc
# 1  0x8640e8086ca548b1:0x477dd129975bfff8  ChIJsUilbAjoQIYR-P9blynRfUc
#
#                                        location_link  \
# 0  https://www.google.com/maps/place/Comfort+Inn+...
# 1  https://www.google.com/maps/place/Comfort+Inn+...
#
#                                         reviews_link  \
# 0  https://search.google.com/local/reviews?placei...
# 1  https://search.google.com/local/reviews?placei...
#
#                                   reviews_per_score  reviews  rating  \
# 0  {"1": 167, "2": 43, "3": 70, "4": 107, "5": 226}      613     3.3
# 1  {"1": 167, "2": 43, "3": 70, "4": 107, "5": 226}      613     3.3
#
# ...

# %%
drop_columns = ["query", "location_link", "reviews_link", "reviews", "rating", "reviews_per_score", "author_link",
                "author_image", "review_img_url", "review_img_urls", "owner_answer", "owner_answer_timestamp",
                "owner_answer_timestamp_datetime_utc", "review_link", "review_timestamp", "review_likes", "reviews_id"]

# %%
tx_df.drop(columns=drop_columns, inplace=True)

# %%
tx_df['review_datetime_utc'] = tx_df['review_datetime_utc'].dt.date

# %%
tx_df.rename(columns={"name":"business_name",
                   "author_title": "user_name", "reviews": "num_of_reviews",
                   "author_id": "user_id", "review_text": "review", "review_rating": "rating",
                   "review_datetime_utc": "date"}, inplace=True)

# %%
tx_df.isna().mean()
# Out:
# business_name    0.00000
# google_id        0.00000
# place_id         0.00000
# review_id        0.00000
# user_name        0.00000
# user_id          0.21745
# review           0.00000
# rating           0.21745
# date             0.00000
# dtype: float64

# %%
tx_df.shape
# Out:
# (2235, 9)

# %%
tx_df["state"] = "TX"

# %% [markdown]
# ## Resto de estados

# %%
def etl(df):
  drop_columns = ["query", "location_link", "reviews_link", "reviews", "rating", "reviews_per_score", "author_link",
                "author_image", "review_img_url", "review_img_urls", "owner_answer", "owner_answer_timestamp",
                "owner_answer_timestamp_datetime_utc", "review_link", "review_timestamp", "review_likes", "reviews_id"]

  df.drop(columns=drop_columns, inplace=True)
  df['review_datetime_utc'] = df['review_datetime_utc'].dt.date
  df.rename(columns={"name":"business_name",
                   "author_title": "user_name", "reviews": "num_of_reviews",
                   "author_id": "user_id", "review_text": "review", "review_rating": "rating",
                   "review_datetime_utc": "date"}, inplace=True)

  return df

# %%
ca_df.shape
# Out:
# (1653, 26)

# %%
ca_df.isna().mean()
# Out:
# query                                  0.000000
# name                                   0.000000
# google_id                              0.000000
# place_id                               0.000000
# location_link                          0.000000
# reviews_link                           0.053237
# reviews_per_score                      0.001210
# reviews                                0.001210
# rating                                 0.001210
# review_id                              0.000000
# author_link                            0.005445
# author_title                           0.005445
# author_id                              0.124017
# author_image                           0.005445
# review_text                            0.005445
# review_img_url                         0.880218
# review_img_urls                        0.880218
# owner_answer                           0.719298
# owner_answer_timestamp                 0.719298
# owner_answer_timestamp_datetime_utc    0.719298
# ...

# %%
ca = etl(ca_df)
ca["state"] = "CA"
ca.head(3)
# Out:
#             business_name                              google_id  \
# 0  1 Hotel West Hollywood  0x80c2bebdd19083f7:0xb4204a5e73ccb389
# 1  1 Hotel West Hollywood  0x80c2bebdd19083f7:0xb4204a5e73ccb389
# 2  1 Hotel West Hollywood  0x80c2bebdd19083f7:0xb4204a5e73ccb389
#
#                       place_id                             review_id  \
# 0  ChIJ94OQ0b2-woARibPMc15KILQ   ChZDSUhNMG9nS0VJQ0FnSUNCNGNmeU53EAE
# 1  ChIJ94OQ0b2-woARibPMc15KILQ   ChZDSUhNMG9nS0VJQ0FnSUNCdXJDMkF3EAE
# 2  ChIJ94OQ0b2-woARibPMc15KILQ  ChdDSUhNMG9nS0VJQ0FnSUNCMU9YWS1nRRAB
#
#        user_name                user_id  \
# 0          JDK -  107527610532594873109
# 1  Barbara Cyzon  105690407172903918990
# 2    Henry Fonda  106930772270942620174
#
#                                               review  rating        date state
# 0  Shower was clogged, no coffee or water for fre...     2.0  2022-12-28    CA
# 1  A beautiful hotel in the best location. Great ...     5.0  2022-12-23    CA
# ...

# %%
ny = etl(ny_df)
ny["state"] = "NY"
ny.head(3)
# Out:
#                          business_name                              google_id  \
# 0  The Manhattan at Times Square Hotel  0x89c258f88254f2c3:0xe0e14597c5400022
# 1  The Manhattan at Times Square Hotel  0x89c258f88254f2c3:0xe0e14597c5400022
# 2  The Manhattan at Times Square Hotel  0x89c258f88254f2c3:0xe0e14597c5400022
#
#                       place_id                             review_id  \
# 0  ChIJw_JUgvhYwokRIgBAxZdF4eA  ChdDSUhNMG9nS0VJQ0FnSUR1bDZta3dBRRAB
# 1  ChIJw_JUgvhYwokRIgBAxZdF4eA  ChdDSUhNMG9nS0VJQ0FnSUR1cDhMZDRRRRAB
# 2  ChIJw_JUgvhYwokRIgBAxZdF4eA   ChZDSUhNMG9nS0VJQ0FnSUNldnI3R2JREAE
#
#               user_name                user_id  \
# 0      Stefania Gennaro  100027077753455034212
# 1     Salvatore Signore  107021945822694485357
# 2  Verified Hotel Guest                    NaN
#
#                                               review  rating        date state
# 0  (Translated by Google) I found myself well ......     5.0  2022-08-31    NY
# ...

# %%
fl = etl(fl_df)
fl["state"] = "FL"
fl.head(3)
# Out:
#                                        business_name  \
# 0  Comfort Inn & Suites Near Universal Orlando Re...
# 1  Comfort Inn & Suites Near Universal Orlando Re...
# 2  Comfort Inn & Suites Near Universal Orlando Re...
#
#                                google_id                     place_id  \
# 0  0x88e77eff6a14f3b9:0xf31cbc021d404afa  ChIJufMUav9-54gR-kpAHQK8HPM
# 1  0x88e77eff6a14f3b9:0xf31cbc021d404afa  ChIJufMUav9-54gR-kpAHQK8HPM
# 2  0x88e77eff6a14f3b9:0xf31cbc021d404afa  ChIJufMUav9-54gR-kpAHQK8HPM
#
#                               review_id             user_name user_id  \
# 0   ChZDSUhNMG9nS0VJQ0FnSUMtN0l2S0hREAE             Anonymous     NaN
# 1  ChdDSUhNMG9nS0VJQ0FnSUNldm82Tmt3RRAB  Verified Hotel Guest     NaN
# 2  ChdDSUhNMG9nS0VJQ0FnSUMtN0x2SzJnRRAB             Anonymous     NaN
#
#                                               review  rating        date state
# 0  (Translated by Google) Excellent hotel, beauti...     NaN  2022-08-30    FL
# ...

# %%
nv = etl(nv_df)
nv["state"] = "NV"
nv.head(3)
# Out:
#         business_name                              google_id  \
# 0  Circus Circus Reno  0x809947369a6d96f1:0x8a35778e09b46c3e
# 1  Circus Circus Reno  0x809947369a6d96f1:0x8a35778e09b46c3e
# 2  Circus Circus Reno  0x809947369a6d96f1:0x8a35778e09b46c3e
#
#                       place_id                             review_id  \
# 0  ChIJ8ZZtmjZHmYARPmy0CY53NYo  ChdDSUhNMG9nS0VJQ0FnSUR1eDQtSnR3RRAB
# 1  ChIJ8ZZtmjZHmYARPmy0CY53NYo  ChdDSUhNMG9nS0VJQ0FnSUNldnU2RzB3RRAB
# 2  ChIJ8ZZtmjZHmYARPmy0CY53NYo  ChdDSUhNMG9nS0VJQ0FnSUNldnZieTBRRRAB
#
#               user_name                user_id  \
# 0           Sierra Wild  106331207821117878375
# 1                Elaine                    NaN
# 2  Verified Hotel Guest                    NaN
#
#                                               review  rating        date state
# 0  Majority of the restaurants were closed comple...     1.0  2022-08-31    NV
# 1  Negative: From the checkout counter to our roo...     NaN  2022-08-30    NV
# ...

# %% [markdown]
# # Concatenar

# %%
df_list = [tx_df, ca, ny, fl, nv]
df = pd.concat(df_list, ignore_index=True)

# %%
df
# Out:
#                                    business_name  \
# 0      Comfort Inn & Suites SW Houston Sugarland
# 1      Comfort Inn & Suites SW Houston Sugarland
# 2      Comfort Inn & Suites SW Houston Sugarland
# 3      Comfort Inn & Suites SW Houston Sugarland
# 4      Comfort Inn & Suites SW Houston Sugarland
# ...                                          ...
# 10751        Super 8 by Wyndham Sparks/Reno Area
# 10752        Super 8 by Wyndham Sparks/Reno Area
# 10753        Super 8 by Wyndham Sparks/Reno Area
# 10754        Super 8 by Wyndham Sparks/Reno Area
# 10755        Super 8 by Wyndham Sparks/Reno Area
#
#                                    google_id                     place_id  \
# 0      0x8640e8086ca548b1:0x477dd129975bfff8  ChIJsUilbAjoQIYR-P9blynRfUc
# 1      0x8640e8086ca548b1:0x477dd129975bfff8  ChIJsUilbAjoQIYR-P9blynRfUc
# 2      0x8640e8086ca548b1:0x477dd129975bfff8  ChIJsUilbAjoQIYR-P9blynRfUc
# 3      0x8640e8086ca548b1:0x477dd129975bfff8  ChIJsUilbAjoQIYR-P9blynRfUc
# ...

# %%
df.isna().mean()
# Out:
# business_name    0.000000
# google_id        0.000000
# place_id         0.000000
# review_id        0.000000
# user_name        0.001116
# user_id          0.174600
# review           0.001116
# rating           0.174600
# date             0.001116
# state            0.000000
# dtype: float64

# %%
df["user_name"].fillna("Desconocido", inplace=True)

# %%
df["user_id"].fillna(1, inplace=True)

# %% [markdown]
# ## Añadiendo hoteles de la tabla reviews a la tabla de business

# %%
business_tabla_reviews = df[["business_name", "google_id", "place_id", "state"]].drop_duplicates()
business_tabla_reviews
# Out:
#                                            business_name  \
# 0              Comfort Inn & Suites SW Houston Sugarland
# 20                             Hyatt Place Houston-North
# 40            Holiday Inn Houston Downtown, an IHG Hotel
# 60     DoubleTree by Hilton Hotel Houston - Greenway ...
# 80                                 Hyatt Regency Houston
# ...                                                  ...
# 9518                              Sonesta ES Suites Reno
# 9543                 Super 8 by Wyndham Sparks/Reno Area
# 9568                  SpringHill Suites by Marriott Reno
# 10291                     Hyatt Place Reno-Tahoe Airport
# 10361                     Homewood Suites by Hilton Reno
#
#                                    google_id                     place_id  \
# 0      0x8640e8086ca548b1:0x477dd129975bfff8  ChIJsUilbAjoQIYR-P9blynRfUc
# 20     0x8640c9e4f49ef8b5:0xf3224340b2d84e66  ChIJtfie9OTJQIYRZk7YskBDIvM
# ...

# %%
business_nueva_data
# Out:
#                                         business_name  \
# 0          Hilton Garden Inn Houston NW America Plaza
# 1       Courtyard by Marriott Houston NW/290 Corridor
# 2                     Hampton Inn Houston-Brookhollow
# 3               HomeTowne Studios Houston - Northwest
# 4                             Comfort Inn Hwy. 290/NW
# ..                                                ...
# 895  Staypineapple, An Artful Hotel, Midtown New York
# 896                          31 Street Broadway Hotel
# 897           Millennium Hilton New York One UN Plaza
# 898                             Incentra Home Chelsea
# 899                                        SIXTY SoHo
#
#                                    category  \
# 0                                     Hotel
# 1           Hotel, Meeting planning service
# 2                                     Hotel
# 3    Extended stay hotel, Hotel, Inn, Motel
# 4                                     Hotel
# ...

# %%
hotels_list = [business_nueva_data, business_tabla_reviews]
business = pd.concat(hotels_list, ignore_index=True)

# %%
business.drop_duplicates(subset=["place_id", "state"], keep="first", inplace=True)

# %% [markdown]
# ## Usuarios

# %%
users = pd.DataFrame()
users["user_id"] = df["user_id"]
users["user_name"] = df["user_name"]

# %%
users.drop_duplicates(inplace=True)

# %%
df.drop(columns="user_name", inplace=True)

# %%
df[df.duplicated(keep=False)].sort_values(by="review")
# Out:
#                                           business_name  \
# 1441                                 Omni Houston Hotel
# 1260                                 Omni Houston Hotel
# 2600         Hampton Inn & Suites Los Angeles/Hollywood
# 2605         Hampton Inn & Suites Los Angeles/Hollywood
# 3133  SLS Hotel, a Luxury Collection Hotel, Beverly ...
# ...                                                 ...
# 2469              Comfort Inn Cockatoo Near LAX Airport
# 2266                                     Air R&R Suites
# 2267                                     Air R&R Suites
# 2508                                       Custom Hotel
# 2509                                       Custom Hotel
#
#                                   google_id                     place_id  \
# 1441  0x8640c148fd8e50d3:0x855269a9c60f8290  ChIJ01CO_UjBQIYRkIIPxqlpUoU
# 1260  0x8640c148fd8e50d3:0x855269a9c60f8290  ChIJ01CO_UjBQIYRkIIPxqlpUoU
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.drop(columns=["state"], inplace=True)

# %% [markdown]
# # Exportando a csv

# %%
users.to_csv("/content/drive/MyDrive/Colab Notebooks/data-nueva/data-nueva-unida/users_nueva_data.csv", sep="|", index=False)

# %%
df.to_csv("/content/drive/MyDrive/Colab Notebooks/data-nueva/data-nueva-unida/reviews_nueva_data.csv", sep="|", index=False)

# %%
business.to_csv("/content/drive/MyDrive/Colab Notebooks/data-nueva/data-nueva-unida/business_nueva_data.csv", sep="|", index=False)
